# %%
# plotting weighted portfolio performance metrics for all methods
from matplotlib import pyplot as plt
import numpy as np

fig = plt.figure()
# fig,ax = plt.subplots(4,2)
index = ["Non-weighted", "PCA", "ICA", "CPD+PCA", "CPD+ICA", "HOSVD+PCA", "HOSVD+ICA", "HOOI+PCA", "HOOI+ICA"]
ar = [31.35, 39.698, 102.408, 55.688, 6.371, 22.314, 24.222, 27.313, 51.331]
cr = [72.527, 95.156, 309.691, 143.453, 13.207, 49.607, 54.312, 62.085, 129.012]
av = [30.513, 33.344, 50.589, 37.148, 4.647, 31.468, 25.086, 29.769, 38.207]
sr = [1.05, 1.17, 1.65, 1.37, 1.30, 0.80, 0.99, 0.96, 1.28]
md = [-32.197, -34.044, -43.127, -37.795, -5.037, -31.359, -25.79, -30.361, -41.088]
sk = [-0.96, -0.97, -0.08, -0.92, -0.69, -0.75, -0.33, -0.88, -1.21]
kt = [9.35, 7.87, 3.96, 6.08, 5.14, 8.10, 1.20, 8.69, 13.81]

fontsize = 14
fsize = 14

ax1 = plt.subplot(4, 2, 1)
ax1.plot(index,ar)
ax1.set_ylabel('Percentage', fontsize=fontsize)
ax1.set_xlabel('Methods', fontsize=fontsize)
ax1.tick_params(axis='x',labelsize=fsize)
ax1.tick_params(axis='y',labelsize=fsize)

ax2 = plt.subplot(4, 2, 2)
ax2.plot(index,cr)
ax2.set_ylabel('Percentage', fontsize=fontsize)
ax2.set_xlabel('Methods', fontsize=fontsize)
ax2.tick_params(axis='x',labelsize=fsize)
ax2.tick_params(axis='y',labelsize=fsize)

ax3 = plt.subplot(4, 2, 3)
ax3.plot(index,av)
ax3.set_ylabel('Percentage', fontsize=fontsize)
ax3.set_xlabel('Methods', fontsize=fontsize)
ax3.tick_params(axis='x',labelsize=fsize)
ax3.tick_params(axis='y',labelsize=fsize)

ax4 = plt.subplot(4, 2, 4)
ax4.plot(index,sr)
ax4.set_ylabel('Value', fontsize=fontsize)
ax4.set_xlabel('Methods', fontsize=fontsize)
ax4.tick_params(axis='x',labelsize=fsize)
ax4.tick_params(axis='y',labelsize=fsize)

ax5 = plt.subplot(4, 2, 5)
ax5.plot(index,md)
ax5.set_ylabel('Percentage', fontsize=fontsize)
ax5.set_xlabel('Methods', fontsize=fontsize)
ax5.tick_params(axis='x',labelsize=fsize)
ax5.tick_params(axis='y',labelsize=fsize)

ax6 = plt.subplot(4, 2, 6)
ax6.plot(index,sk)
ax6.set_ylabel('Value', fontsize=fontsize)
ax6.set_xlabel('Methods', fontsize=fontsize)
ax6.tick_params(axis='x',labelsize=fsize)
ax6.tick_params(axis='y',labelsize=fsize)

ax7 = plt.subplot(4, 2, 7)
ax7.plot(index,kt)
ax7.set_ylabel('Value', fontsize=fontsize)
ax7.set_xlabel('Methods', fontsize=fontsize)
ax7.tick_params(axis='x',labelsize=fsize)
ax7.tick_params(axis='y',labelsize=fsize)

ax1.set_title("Annual Return",fontsize=14)
ax2.set_title("Cumulative Returns",fontsize=14)
ax3.set_title("Annual Volatility",fontsize=14)
ax4.set_title("Sharpe Ratio",fontsize=14)
ax5.set_title("Maximum Drawdown",fontsize=14)
ax6.set_title("Skew",fontsize=14)
ax7.set_title("Kurtosis",fontsize=14)

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()
ax7.grid()
        
fig.set_size_inches(32,40)

# %%
# plotting top 10 stocks portfolio performance metrics for all methods
fig = plt.figure()
index = ["Non-weighted", "PCA", "ICA", "CPD+PCA", "CPD+ICA", "HOSVD+PCA", "HOSVD+ICA", "HOOI+PCA", "HOOI+ICA"]
ar = [31.35, 46.763, 40.18, 32.815, 38.875, 22.491, 40.845, 37.719, 36.541]
cr = [72.527, 115.393, 96.505, 77.822, 93.269, 50.039, 98.373, 89.664, 86.434]
av = [30.513, 32.043, 31.891, 31.635, 33.403, 32.462, 30.359, 33.879, 30.619]
sr = [1.05, 1.25, 1.22, 1.03, 1.15, 0.79, 1.28, 1.12, 1.17]
md = [-32.197, -35.424, -32.546, -33.128, -33.858, -32.383, -33.726, -33.678, -33.056]
sk = [-0.96, -0.96, -1.02, -0.81, -0.92, -0.78, -1.28, -0.90, -1.13]
kt = [9.35, 6.00, 7.12, 8.32, 7.79, 8.89, 10.29, 8.76, 10.96]

fontsize = 14
fsize = 14

ax1 = plt.subplot(4, 2, 1)
ax1.plot(index,ar)
ax1.set_ylabel('Percentage', fontsize=fontsize)
ax1.set_xlabel('Methods', fontsize=fontsize)
ax1.tick_params(axis='x',labelsize=fsize)
ax1.tick_params(axis='y',labelsize=fsize)

ax2 = plt.subplot(4, 2, 2)
ax2.plot(index,cr)
ax2.set_ylabel('Percentage', fontsize=fontsize)
ax2.set_xlabel('Methods', fontsize=fontsize)
ax2.tick_params(axis='x',labelsize=fsize)
ax2.tick_params(axis='y',labelsize=fsize)

ax3 = plt.subplot(4, 2, 3)
ax3.plot(index,av)
ax3.set_ylabel('Percentage', fontsize=fontsize)
ax3.set_xlabel('Methods', fontsize=fontsize)
ax3.tick_params(axis='x',labelsize=fsize)
ax3.tick_params(axis='y',labelsize=fsize)

ax4 = plt.subplot(4, 2, 4)
ax4.plot(index,sr)
ax4.set_ylabel('Value', fontsize=fontsize)
ax4.set_xlabel('Methods', fontsize=fontsize)
ax4.tick_params(axis='x',labelsize=fsize)
ax4.tick_params(axis='y',labelsize=fsize)

ax5 = plt.subplot(4, 2, 5)
ax5.plot(index,md)
ax5.set_ylabel('Percentage', fontsize=fontsize)
ax5.set_xlabel('Methods', fontsize=fontsize)
ax5.tick_params(axis='x',labelsize=fsize)
ax5.tick_params(axis='y',labelsize=fsize)

ax6 = plt.subplot(4, 2, 6)
ax6.plot(index,sk)
ax6.set_ylabel('Value', fontsize=fontsize)
ax6.set_xlabel('Methods', fontsize=fontsize)
ax6.tick_params(axis='x',labelsize=fsize)
ax6.tick_params(axis='y',labelsize=fsize)

ax7 = plt.subplot(4, 2, 7)
ax7.plot(index,kt)
ax7.set_ylabel('Value', fontsize=fontsize)
ax7.set_xlabel('Methods', fontsize=fontsize)
ax7.tick_params(axis='x',labelsize=fsize)
ax7.tick_params(axis='y',labelsize=fsize)

ax1.set_title("Annual Return",fontsize=14)
ax2.set_title("Cumulative Returns",fontsize=14)
ax3.set_title("Annual Volatility",fontsize=14)
ax4.set_title("Sharpe Ratio",fontsize=14)
ax5.set_title("Maximum Drawdown",fontsize=14)
ax6.set_title("Skew",fontsize=14)
ax7.set_title("Kurtosis",fontsize=14)

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()
ax7.grid()
        
fig.set_size_inches(32,40)
